# %%
from  sklearn.naive_bayes import BernoulliNB
import pandas as pd
from pandas import DataFrame,Series
import sys
import os
import cv2
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve,auc

import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score,roc_auc_score,roc_curve,auc
import matplotlib.pyplot as plt
SHAPE = (30,30)

# %%
def getImageData(directory):
   s = 1
   feature_list = list()
   label_list   = list()
   num_classes = 0
   for root, dirs, files in os.walk(directory):
      for d in dirs:
         num_classes += 1
         images = os.listdir(root+d)
         for image in images:
            s += 1
            label_list.append(d)
            feature_list.append(extractFeaturesFromImage(root + d + "/" + image))

   return np.asarray(feature_list), np.asarray(label_list)


def extractFeaturesFromImage(image_file):
   img = cv2.imread(image_file)
   img = cv2.resize(img, SHAPE, interpolation = cv2.INTER_CUBIC)
   img = img.flatten()
   img = img / np.mean(img)
   return img

# %%
directory ="C:/Users/11409/Desktop/444/"

feature_array, label_array = getImageData(directory)

X_train, X_test, y_train, y_test = train_test_split(feature_array, label_array, test_size = 0.3, random_state = 42)
model=BernoulliNB().fit(X_train, y_train)

# %%
Ypred =  model.predict_proba(X_test)[:, 1]

# %%
print(Ypred)
# Out:
# [3.09631889e-001 3.79895172e-059 1.98979086e-155 ... 1.00000000e+000
#  1.00000000e+000 6.38215433e-105]

# %%
y_test_predict = model.predict(X_test)
y_train_predict = model.predict(X_train)
for i in range(len(y_test)):
      if y_test[i]=='yes':
         y_test[i]='1'
      else:
        y_test[i]='0'
for i in range(len(y_train_predict)):
       if y_train_predict[i] == 'yes':
          y_train_predict[i] ='1' 
       else:
          y_train_predict[i] ='0'
for i in range(len(y_test)):
         if y_test_predict[i] == 'yes':
            y_test_predict[i] = '1'
         else:
            y_test_predict[i] = '0'
for i in range(len(y_train)):
        if y_train[i] == 'yes':
            y_train[i] = '1'
        else:
            y_train[i] = '0'
    # 测试准确率
y_true = y_test
y_pred = y_test_predict
cm = confusion_matrix(y_true,y_pred)
cm = pd.DataFrame(cm,columns=["healthy","cancer"],index=["healthy","cancer"])
sns.heatmap(cm,cmap="YlGnBu_r",fmt="d",annot=True)
accuracy_train = accuracy_score(y_train, y_train_predict)
print(accuracy_train)
  # 测试准确率
  # 测试准确率

accuracy_test = accuracy_score(y_test, y_test_predict)
print(accuracy_test)
# Out:
# 0.5851190476190476
# 0.565

# %%
df=DataFrame()
df['label']=Series(y_test)
df['probability']=Series(Ypred)
df.to_csv('C:/Users/11409/Desktop/by_roc.csv')

# %%
def ROC(path):
    df=pd.read_csv(path) 
    y_test=df['label']
    y_score=df['probability']   
    fpr,tpr,threshold = roc_curve(y_test, y_score) ###计算真正率和假正率  
    roc_auc = auc(fpr,tpr) ###计算auc的值
    return fpr,tpr,roc_auc
plt.figure()
lw = 0.9
plt.figure(figsize=(6,6))
ax1=plt.subplot(1,1,1)
ak='C:/Users/11409/Desktop/by_roc.csv'
fpr,tpr,roc_auc=ROC(path=ak)
print(roc_auc)
ax1.plot(fpr, tpr, color='#2F7FC1',lw=lw)
ax1.plot([0, 1], [0, 1], color='SlateGray', lw=0.8, linestyle='--')  
ax1.set_xlim([-0.02, 1.0])  
ax1.set_ylim([0.0, 1.02])  
ax1.set_xlabel('False Positive Rate',fontsize=14)  
ax1.set_ylabel('True Positive Rate',fontsize=14) 
plt.legend(loc="lower right")
plt.savefig('C:/Users/11409/Desktop/by.png')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 0.6046706187904625

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_test_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.60      0.42      0.50      1827
#            1       0.54      0.71      0.62      1773
#
#     accuracy                           0.56      3600
#    macro avg       0.57      0.57      0.56      3600
# weighted avg       0.57      0.56      0.56      3600
